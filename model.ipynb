# %%
pip install opencv-python
# Out:
# ...
#   Using cached opencv_python-4.4.0.46-cp37-cp37m-win_amd64.whl (33.5 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow
# Out:
# ...
#   Using cached tensorflow-2.3.1-cp37-cp37m-win_amd64.whl (342.5 MB)
# ...
#   Using cached tensorflow_estimator-2.3.0-py2.py3-none-any.whl (459 kB)
# ...
#   Using cached absl_py-0.11.0-py3-none-any.whl (127 kB)
# ...
#   Using cached gast-0.3.3-py2.py3-none-any.whl (9.7 kB)
# ...
#   Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Processing c:\users\pranay\appdata\local\pip\cache\wheels\3f\e3\ec\8a8336ff196023622fbcb36de0c5a5c218cbb24111d1d4c7f2\termcolor-1.1.0-py3-none-any.whl
# ...
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# ...
#   Using cached protobuf-3.14.0-cp37-cp37m-win_amd64.whl (798 kB)
# ...
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# ...
#   Using cached grpcio-1.34.0-cp37-cp37m-win_amd64.whl (2.9 MB)
# ...
#   Using cached tensorboard-2.4.0-py3-none-any.whl (10.6 MB)
# ...
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# ...
#   Using cached tensorboard_plugin_wit-1.7.0-py3-none-any.whl (779 kB)
# ...
#   Using cached Markdown-3.3.3-py3-none-any.whl (96 kB)
# ...

# %%
pip update --all
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: unknown command "update"

# %%
import numpy as np
import os
import matplotlib.pyplot as pty
from imutils import paths

from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import AveragePooling2D
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input

from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import classification_report

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

# %%
dataset=r'C:\Users\PRANAY\Desktop\dataset'
imagepaths=list(paths.list_images(dataset))

# %%
imagepaths
# Out:
# ['C:\\Users\\PRANAY\\Desktop\\dataset\\without_mask\\0.jpg',
#  'C:\\Users\\PRANAY\\Desktop\\dataset\\without_mask\\0_0_aidai_0014.jpg',
#  'C:\\Users\\PRANAY\\Desktop\\dataset\\without_mask\\0_0_aidai_0029.jpg',
#  'C:\\Users\\PRANAY\\Desktop\\dataset\\without_mask\\0_0_aidai_0043.jpg',
#  'C:\\Users\\PRANAY\\Desktop\\dataset\\without_mask\\0_0_aidai_0074.jpg',
#  'C:\\Users\\PRANAY\\Desktop\\dataset\\without_mask\\0_0_aidai_0084.jpg',
#  'C:\\Users\\PRANAY\\Desktop\\dataset\\without_mask\\0_0_aidai_0136.jpg',
#  'C:\\Users\\PRANAY\\Desktop\\dataset\\without_mask\\0_0_anhu_0004.jpg',
#  'C:\\Users\\PRANAY\\Desktop\\dataset\\without_mask\\0_0_anhu_0020.jpg',
#  'C:\\Users\\PRANAY\\Desktop\\dataset\\without_mask\\0_0_anhu_0025.jpg',
#  'C:\\Users\\PRANAY\\Desktop\\dataset\\without_mask\\0_0_anhu_0027.jpg',
#  'C:\\Users\\PRANAY\\Desktop\\dataset\\without_mask\\0_0_anhu_0056.jpg',
#  'C:\\Users\\PRANAY\\Desktop\\dataset\\without_mask\\0_0_anhu_0057.jpg',
# ...

# %%
data=[]
labels=[]

for i in imagepaths:
    label=i.split(os.path.sep)[-2]
    labels.append(label)
    image=load_img(i,target_size=(224,224))
    image=img_to_array(image)
    image=preprocess_input(image)
    data.append(image)
# Out:
# I:\ana\lib\site-packages\PIL\Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "

# %%
data=np.array(data,dtype='float32')
labels=np.array(labels)

# %%
data.shape
# Out:
# (3833, 224, 224, 3)

# %%
labels
# Out:
# array(['without_mask', 'without_mask', 'without_mask', ..., 'with_mask',
#        'with_mask', 'with_mask'], dtype='<U12')

# %%
lb=LabelBinarizer()
labels=lb.fit_transform(labels)
labels=to_categorical(labels)

# %%
labels
# Out:
# array([[0., 1.],
#        [0., 1.],
#        [0., 1.],
#        ...,
#        [1., 0.],
#        [1., 0.],
#        [1., 0.]], dtype=float32)

# %%
train_X,test_X,train_Y,test_Y=train_test_split(data,labels,test_size=0.20,stratify=labels,random_state=10)

# %%
train_X.shape
# Out:
# (3066, 224, 224, 3)

# %%
train_Y.shape
# Out:
# (3066, 2)

# %%
test_X.shape
# Out:
# (767, 224, 224, 3)

# %%
test_Y.shape
# Out:
# (767, 2)

# %%
aug=ImageDataGenerator(rotation_range=20,zoom_range=0.15,width_shift_range=0.2,height_shift_range=0.15,horizontal_flip=True,vertical_flip=True,fill_mode='nearest')

# %%
aug

# %%
baseModel=MobileNetV2(weights='imagenet',include_top=False,input_tensor=Input(shape=(224,224,3)))
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.

# %%
baseModel.summary()
# Out:
# Model: "mobilenetv2_1.00_224"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# Conv1_pad (ZeroPadding2D)       (None, 225, 225, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# Conv1 (Conv2D)                  (None, 112, 112, 32) 864         Conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_Conv1 (BatchNormalization)   (None, 112, 112, 32) 128         Conv1[0][0]
# __________________________________________________________________________________________________
# Conv1_relu (ReLU)               (None, 112, 112, 32) 0           bn_Conv1[0][0]
# ...

# %%
headModel=baseModel.output
headModel=AveragePooling2D(pool_size=(7,7))(headModel)
headModel=Flatten(name='Flatten')(headModel)
headModel=Dense(128,activation='relu')(headModel)
headModel=Dropout(0.5)(headModel)
headModel=Dense(2,activation='softmax')(headModel)

model=Model(inputs=baseModel.input,outputs=headModel)

# %%
for layer in baseModel.layers:
    layer.trainable=False

# %%
learning_rate=0.0001
Epochs=5
BS=12

opt=Adam(lr=learning_rate,decay=learning_rate/Epochs)
model.compile(loss='binary_crossentropy',optimizer=opt,metrics=['accuracy'])

H=model.fit(
    aug.flow(train_X,train_Y,batch_size=BS),
    steps_per_epoch=len(train_X)//BS, 
    validation_data=(test_X,test_Y),
    validation_steps=len(test_X)//BS,
    epochs=Epochs
)


model.save(r'C:\Users\PRANAY\.keras\models\mobilenet_v2.model')
# Out:
# Epoch 1/5
# ...
# 255/255 [==============================] - 72s 283ms/step - loss: 0.1094 - accuracy: 0.9630 - val_loss: 0.0626 - val_accuracy: 0.9817
# Epoch 2/5
# 255/255 [==============================] - 60s 233ms/step - loss: 0.0866 - accuracy: 0.9682
# Epoch 3/5
# 255/255 [==============================] - 60s 234ms/step - loss: 0.0800 - accuracy: 0.9725
# Epoch 4/5
# 255/255 [==============================] - 60s 235ms/step - loss: 0.0622 - accuracy: 0.9761
# Epoch 5/5
# 255/255 [==============================] - 60s 234ms/step - loss: 0.0680 - accuracy: 0.9758
# INFO:tensorflow:Assets written to: C:\Users\PRANAY\.keras\models\mobilenet_v2.model\assets

# %%
predict=model.predict(test_X,batch_size=BS)
predict=np.argmax(predict,axis=1)
print(classification_report)
# Out:
# <function classification_report at 0x0000020298EE0798>
